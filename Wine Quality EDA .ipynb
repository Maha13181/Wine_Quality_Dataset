# %%
#step 1 : importing all the required python libraries 
import os 
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 2 : uploading required data set to perform EDA 
os.chdir('B:\\Data science')

# %%
wine_dataset = pd.read_csv("winequalityN.csv")

# %%
wine_dataset.shape
# Out:
# (6497, 13)

# %%
#step 3 :uploading data  head information 
wine_dataset.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
#step 3 :uploading data tail information 
wine_dataset.tail()
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 6492       0.58     10.5        5
# ...

# %%
#step:4 checking of missing values 
wine_dataset.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
#step:4 checking the statistical data
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
#Step:5 removing the missing values rows
wine_dataset.dropna()
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6491    red            6.8             0.620         0.08             1.9
# 6492    red            6.2             0.600         0.08             2.0
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#step:6 removing using coloumns & and if any one of the data missing in the coloumn if all the values are missed
wine_dataset.dropna(axis="columns" , how="any")
# Out:
#        type  free sulfur dioxide  total sulfur dioxide  density  alcohol  \
# 0     white                 45.0                 170.0  1.00100      8.8
# 1     white                 14.0                 132.0  0.99400      9.5
# 2     white                 30.0                  97.0  0.99510     10.1
# 3     white                 47.0                 186.0  0.99560      9.9
# 4     white                 47.0                 186.0  0.99560      9.9
# ...     ...                  ...                   ...      ...      ...
# 6492    red                 32.0                  44.0  0.99490     10.5
# 6493    red                 39.0                  51.0  0.99512     11.2
# 6494    red                 29.0                  40.0  0.99574     11.0
# 6495    red                 32.0                  44.0  0.99547     10.2
# 6496    red                 18.0                  42.0  0.99549     11.0
#
#       quality
# 0           6
# 1           6
# 2           6
# 3           6
# ...

# %%
##step:6 removing using index & all if all of the data missing in the coloumn if all the values are missed
wine_dataset.dropna(axis="index" , how="all")
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#step:6 Finding the mean values
wine_dataset.mean()
# Out:
# C:\Users\mahad\AppData\Local\Temp\ipykernel_10220\35758196.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   wine_dataset.mean()
# fixed acidity             7.216579
# volatile acidity          0.339691
# citric acid               0.318722
# residual sugar            5.444326
# chlorides                 0.056042
# free sulfur dioxide      30.525319
# total sulfur dioxide    115.744574
# density                   0.994697
# pH                        3.218395
# sulphates                 0.531215
# alcohol                  10.491801
# quality                   5.818378
# dtype: float64

# %%
#step:7 filling the missing data in dataset
winedata= wine_dataset.fillna(mean)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 #step:7 filling the missing data in dataset
# ----> 2 winedata= wine_dataset.fillna(mean)
#
# NameError: name 'mean' is not defined
